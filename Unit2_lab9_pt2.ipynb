# %% [markdown]
# # Unit 2 Lab 9, Part 2

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import sqlalchemy as alch
from getpass import getpass

# %%
# create variable for password
password = getpass("sql password: ")
# Out:
# sql password: ········

# %%
# set database, create connection as engine
dbName = "sakila"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %% [markdown]
# ## Create a Python connection with SQL database and retrieve the results of the last two queries (also mentioned below) as dataframes:

# %% [markdown]
# ### Check the number of rentals for each customer for May

# %%
# df for May rentals
query_may = "SELECT * FROM rentals_may"
rentals_may = pd.read_sql_query(query_may, engine)

# %%
# number of rentals for the month of May
len(rentals_may)
# Out:
# 1156

# %% [markdown]
# ### Check the number of rentals for each customer for June

# %%
# df for June rentals
query_june = "SELECT * FROM rentals_june"
rentals_june = pd.read_sql_query(query_june, engine)

# %%
# number of rentals for the month of June
len(rentals_june)
# Out:
# 2311

# %% [markdown]
# ### Write a function that checks if customer borrowed more or less films in the month of June as compared to May.
# #### Hint: For this part, you can create a join between the two dataframes created before, using the merge function available for pandas dataframes.

# %%
# checking both dataframes
rentals_may.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53

# %%
rentals_june.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0       1158 2005-06-14 22:53:33          1632          416
# 1       1159 2005-06-14 22:55:13          4395          516
# 2       1160 2005-06-14 23:00:34          2795          239
# 3       1161 2005-06-14 23:07:08          1690          285
# 4       1162 2005-06-14 23:09:38           987          310
#
#           return_date  staff_id         last_update
# 0 2005-06-18 21:37:33         2 2006-02-15 21:30:53
# 1 2005-06-17 02:11:13         1 2006-02-15 21:30:53
# 2 2005-06-18 01:58:34         2 2006-02-15 21:30:53
# 3 2005-06-21 17:12:08         1 2006-02-15 21:30:53
# 4 2005-06-23 22:00:38         1 2006-02-15 21:30:53

# %%
# df merging both May and June rentals on customer_id
# decided on outer join to get all customer_ids
may_june = rentals_may.merge(rentals_june, how="outer", on='customer_id', suffixes = ('_m', '_j'))
may_june
# Out:
#       rental_id_m       rental_date_m  inventory_id_m  customer_id  \
# 0             1.0 2005-05-24 22:53:30           367.0          130
# 1             1.0 2005-05-24 22:53:30           367.0          130
# 2             1.0 2005-05-24 22:53:30           367.0          130
# 3             1.0 2005-05-24 22:53:30           367.0          130
# 4             1.0 2005-05-24 22:53:30           367.0          130
# ...           ...                 ...             ...          ...
# 4705          NaN                 NaT             NaN          487
# 4706          NaN                 NaT             NaN          555
# 4707          NaN                 NaT             NaN          335
# 4708          NaN                 NaT             NaN          226
# 4709          NaN                 NaT             NaN          226
#
#            return_date_m  staff_id_m       last_update_m  rental_id_j  \
# 0    2005-05-26 22:04:30         1.0 2006-02-15 21:30:53       1630.0
# ...

# %%
# new df to get the needed columns like count of rentals per customer_id
rent = pd.DataFrame(may_june.groupby('customer_id')[['rental_id_m', 'rental_id_j']].count())
rent
# Out:
#              rental_id_m  rental_id_j
# customer_id
# 1                     14           14
# 2                      1            1
# 3                      8            8
# 4                      0            6
# 5                     15           15
# ...                  ...          ...
# 595                    2            2
# 596                   12           12
# 597                    6            6
# 598                    0            1
# 599                    4            4
#
# [598 rows x 2 columns]

# %%
# copying df... just in case!
rent_diff = rent.copy()
col_name = ['may_count', 'june_count']
rent_diff.columns = col_name
rent_diff
# Out:
#              may_count  june_count
# customer_id
# 1                   14          14
# 2                    1           1
# 3                    8           8
# 4                    0           6
# 5                   15          15
# ...                ...         ...
# 595                  2           2
# 596                 12          12
# 597                  6           6
# 598                  0           1
# 599                  4           4
#
# [598 rows x 2 columns]

# %%
# decided to create another column with the difference between counts to make the next steps easier
rent_diff['diff'] = rent_diff.june_count - rent_diff.may_count
rent_diff
# Out:
#              may_count  june_count  diff
# customer_id
# 1                   14          14     0
# 2                    1           1     0
# 3                    8           8     0
# 4                    0           6     6
# 5                   15          15     0
# ...                ...         ...   ...
# 595                  2           2     0
# 596                 12          12     0
# 597                  6           6     0
# 598                  0           1     1
# 599                  4           4     0
#
# [598 rows x 3 columns]

# %%
rent_diff.isna().any()
# Out:
# may_count     False
# june_count    False
# diff          False
# dtype: bool

# %%
# option 1 with apply lambda
def rent_change(col):
    '''This function will check the difference between the customer rentals between the months of May and June.
    Results will be as follows in the column rent:
    up = June rentals are higher than May rentals
    down = June rentals are lower than May rentals
    equal = No change / Same rentals on both months
    '''
    return col.apply(lambda x : 'up' if x > 0 else('down' if x < 0 else 'equal'))
rent_diff['change'] = rent_change(rent_diff['diff'])

# %%
#check
rent_diff.sample(10)
# Out:
#              may_count  june_count  diff change
# customer_id
# 65                   4           4     0  equal
# 235                  4           4     0  equal
# 108                 10          10     0  equal
# 527                  0           4     4     up
# 181                  4           4     0  equal
# 286                  2           2     0  equal
# 357                 12          12     0  equal
# 93                   6           6     0  equal
# 105                 12          12     0  equal
# 441                  2           2     0  equal

# %%
rent_diff.change.value_counts()
# Out:
# equal    512
# up        78
# down       8
# Name: change, dtype: int64

# %%
# option 2 with np.select()
# codition list
condition = [
    (rent_diff['diff'] > 0),
    (rent_diff['diff'] < 0),
    (rent_diff['diff'] == 0)]
choice = ['up', 'down', 'equal']

rent_diff['change2'] = np.select(condition, choice, default=0)

# %%
rent_diff.sample(10)
# Out:
#              may_count  june_count  diff change change2
# customer_id
# 564                  2           2     0  equal   equal
# 274                 12          12     0  equal   equal
# 83                  12          12     0  equal   equal
# 585                  0           4     4     up      up
# 337                  6           6     0  equal   equal
# 34                   0           3     3     up      up
# 508                  2           2     0  equal   equal
# 513                  3           3     0  equal   equal
# 70                   1           1     0  equal   equal
# 188                  0           4     4     up      up

# %%
# So I guess my question is which option is better and why??? Please enlighten meeeeeeeeeee...
